# %%
from regressao_exponencial import Regressão_Exponencial
from regressao_linear import Regressão_Linear
from regressao_logaritmica import Regressão_logaritmica
from regressao_por_potencia import Regressão_potência
# Out:
# 1.0989417989417989
# 1.1166666666666665
# 1.0992559523809524

# %%
x = [1, 2, 3, 4]
y = [3, 5, 6, 9]

Regressão_Linear(x, y)
# Out:
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# f(x) = 1.9000*x + (1.0000)
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
#  R^2:    0.9627
#  f = bx + a
#  b =    1.9000
#  a =    1.0000
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-

# %%
x = [1, 2, 3, 4]
y = [3, 5, 6, 9]

Regressão_logaritmica(x, y)
# Out:
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# f(x) = 3.9294*ln(x) + (2.6281)
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
#  R^2:    0.8928
#  f = bx + a
#  b =    3.9294
#  a =    2.6281
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-

# %%
x = [1, 2, 3, 4]
y = [3, 5, 6, 9]

Regressão_Exponencial(x, y)
# Out:
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# f(x) = 2.2361*e^(0.3478*x)
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
#  R^2:    0.9711
#  f = bx + a
#  b =    0.3478
#  a =    2.2361
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-

# %%
x = [1, 2, 3, 4]
y = [3, 5, 6, 9]

Regressão_potência(x, y)
# Out:
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
# f(x) = 2.9486*x^(0.7463)
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
#  R^2:    0.9695
#  f = bx + a
#  b =    0.7463
#  a =    1.0813
# -=--=--=--=--=--=--=--=--=--=--=--=--=--=--=-
